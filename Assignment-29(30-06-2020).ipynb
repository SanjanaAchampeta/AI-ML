# %% [markdown]
# ### CSE-221710304051-Sanjana

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/wbcd.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.isnull().sum()
# Out:
# id                   0
# diagnosis            0
# radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# points_mean          0
# symmetry_mean        0
# dimension_mean       0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# points_se            0
# symmetry_se          0
# dimension_se         0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# points_worst         0
# symmetry_worst       0
# dimension_worst      0
# dtype: int64

# %% [markdown]
# ##### 1.) Check the descriptive statistics of the dataset

# %%
df1=df.drop(columns=['id'])
df1.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# count       569.000000        569.000000      569.000000   569.000000
# mean          0.096360          0.104341        0.088799     0.048919
# std           0.014064          0.052813        0.079720     0.038803
# min           0.052630          0.019380        0.000000     0.000000
# ...

# %%
df1=df.drop(columns=['id'])
df1.describe().T
# Out:
#                    count        mean         std         min         25%  \
# radius_mean        569.0   14.127292    3.524049    6.981000   11.700000
# texture_mean       569.0   19.289649    4.301036    9.710000   16.170000
# perimeter_mean     569.0   91.969033   24.298981   43.790000   75.170000
# area_mean          569.0  654.889104  351.914129  143.500000  420.300000
# smoothness_mean    569.0    0.096360    0.014064    0.052630    0.086370
# compactness_mean   569.0    0.104341    0.052813    0.019380    0.064920
# concavity_mean     569.0    0.088799    0.079720    0.000000    0.029560
# points_mean        569.0    0.048919    0.038803    0.000000    0.020310
# symmetry_mean      569.0    0.181162    0.027414    0.106000    0.161900
# dimension_mean     569.0    0.062798    0.007060    0.049960    0.057700
# radius_se          569.0    0.405172    0.277313    0.111500    0.232400
# texture_se         569.0    1.216853    0.551648    0.360200    0.833900
# ...

# %% [markdown]
# ##### 2.)Visualize some of those columns and find out if you observe any pattern

# %%
# Histogram
df1.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A1F8457D88>,
# ...
#       dtype=object)

# %%
# Boxplot
for i in df1.select_dtypes(include=['int64','float64']).columns:
    sns.boxplot(df1[i])
    plt.show()

# %% [markdown]
# ##### 3.)Find the correlation in the data and visualize it

# %%
df1.corr()
# Out:
#                    radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean           1.000000      0.323782        0.997855   0.987357
# texture_mean          0.323782      1.000000        0.329533   0.321086
# perimeter_mean        0.997855      0.329533        1.000000   0.986507
# area_mean             0.987357      0.321086        0.986507   1.000000
# smoothness_mean       0.170581     -0.023389        0.207278   0.177028
# compactness_mean      0.506124      0.236702        0.556936   0.498502
# concavity_mean        0.676764      0.302418        0.716136   0.685983
# points_mean           0.822529      0.293464        0.850977   0.823269
# symmetry_mean         0.147741      0.071401        0.183027   0.151293
# dimension_mean       -0.311631     -0.076437       -0.261477  -0.283110
# radius_se             0.679090      0.275869        0.691765   0.732562
# texture_se           -0.097317      0.386358       -0.086761  -0.066280
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df1.corr(),annot=True)

# %% [markdown]
# ##### 4.) Visualize the frequency of the output categories

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df['diagnosis'].value_counts().plot(kind='bar')

# %% [markdown]
# ##### 5.) Apply the KNN Algorithm to the dataset without applying scaling operation and try to compare the results before scaling and after scaling.

# %%
X = df.drop(['id','diagnosis'],axis=1)
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        12.32         12.39           78.85      464.1          0.10280
# 1        10.60         18.95           69.28      346.4          0.09688
# 2        11.04         16.83           70.92      373.2          0.10770
# 3        11.28         13.39           73.00      384.8          0.11640
# 4        15.19         13.21           97.65      711.8          0.07963
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0           0.06981         0.03987      0.03700         0.1959
# 1           0.11470         0.06387      0.02642         0.1922
# 2           0.07804         0.03046      0.02480         0.1714
# 3           0.11360         0.04635      0.04796         0.1771
# 4           0.06934         0.03393      0.02657         0.1721
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y = df.diagnosis
y.head()
# Out:
# 0    B
# 1    B
# 2    B
# 3    B
# 4    B
# Name: diagnosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (398, 30)
# (171, 30)
# (398,)
# (171,)

# %% [markdown]
# ###### Now we are scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Scaling for training data
scaled_X_train = pd.DataFrame(scaler.fit_transform(X_train),columns=X_train.columns)
scaled_X_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0      -0.625972      2.027343       -0.648485  -0.625252        -0.868174
# 1       2.863469      0.181582        3.040948   3.154228         3.367497
# 2      -0.611730      0.760825       -0.566800  -0.610060        -1.922704
# 3      -1.290248     -0.301120       -1.296600  -1.072999        -0.956637
# 4      -0.868097     -1.455008       -0.891889  -0.798962         0.056470
# ..           ...           ...             ...        ...              ...
# 393     0.020642      0.721749        0.052850  -0.088357         0.495975
# 394     0.108947      0.487293        0.203018  -0.045359         0.608308
# 395    -1.468566     -0.117233       -1.337443  -1.192819         0.206716
# 396    -0.717125     -0.744746       -0.701291  -0.688315         1.127850
# 397    -0.654458     -1.094131       -0.593203  -0.653057         1.296350
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# ...

# %%
# Scaling for testing data
# Testing the data based on training data
scaled_X_test = pd.DataFrame(scaler.fit_transform(X_test),columns=X_test.columns)
scaled_X_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.320999      0.724172        0.267279   0.199290        -0.363441
# 1       3.324203     -0.372721        3.430525   3.827199         1.432168
# 2      -0.054755      0.789120       -0.005301  -0.147224         1.808405
# 3       0.871916      0.016965        0.930845   0.708853         1.373150
# 4      -0.628273     -1.200201       -0.679146  -0.599174        -1.280426
# ..           ...           ...             ...        ...              ...
# 166    -0.693253      1.183616       -0.667634  -0.665736        -0.212209
# 167     2.346679      0.158887        2.550703   2.426041         2.737931
# 168    -0.484187     -0.257258       -0.513460  -0.506882        -0.660004
# 169    -0.484187      0.825202       -0.517160  -0.489543        -1.000831
# 170    -0.611322     -0.584402       -0.483859  -0.586030         1.004291
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=6,metric='euclidean')

knn.fit(scaled_X_train,y_train) #scaled
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')

# %%
# Without Scaling
knn1 = KNeighborsClassifier(n_neighbors=6,metric='euclidean')
knn1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')

# %%
# Predictions on the data
# Syntax:objectname.predict(Input)
y_train_pred = knn.predict(scaled_X_train) #scaled
y_train_pred
# Out:
# array(['B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M',
#        'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M',
#        'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B',
# ...

# %%
#Without Scaling
y_train_pred1 = knn1.predict(X_train)
y_train_pred1
# Out:
# array(['B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M',
#        'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B',
# ...

# %%
#scaled
from sklearn.metrics import classification_report
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.96      0.99      0.98       243
#            M       0.99      0.94      0.96       155
#
#     accuracy                           0.97       398
#    macro avg       0.98      0.97      0.97       398
# weighted avg       0.97      0.97      0.97       398

# %%
# Without Scaling
from sklearn.metrics import classification_report
print(classification_report(y_train,y_train_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.98      0.95       243
#            M       0.97      0.88      0.92       155
#
#     accuracy                           0.94       398
#    macro avg       0.95      0.93      0.94       398
# weighted avg       0.94      0.94      0.94       398

# %%
# Checking for optimum k-value
# Build the models with multiple k values
#scaled
from sklearn.metrics import accuracy_score
scores =[]
for k in range(1,20):
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(scaled_X_train,y_train)
    pred_test = knn_model.predict(scaled_X_test)
    scores.append(accuracy_score(y_test,pred_test))
scores
# Out:
# [0.9707602339181286,
#  0.9649122807017544,
#  0.9707602339181286,
#  0.9649122807017544,
#  0.9590643274853801,
#  0.9649122807017544,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9649122807017544,
#  0.9649122807017544,
#  0.9590643274853801,
#  0.9707602339181286,
#  0.9707602339181286,
#  0.9766081871345029,
#  0.9766081871345029,
#  0.9707602339181286,
#  0.9707602339181286,
#  0.9707602339181286,
#  0.9766081871345029]

# %%
# Without Scaling
from sklearn.metrics import accuracy_score
scores1 =[]
for k in range(1,20):
    knn_model1 = KNeighborsClassifier(n_neighbors=k)
    knn_model1.fit(X_train,y_train)
    pred_test1 = knn_model1.predict(X_test)
    scores1.append(accuracy_score(y_test,pred_test1))
scores1
# Out:
# [0.9064327485380117,
#  0.9239766081871345,
#  0.9239766081871345,
#  0.9181286549707602,
#  0.9239766081871345,
#  0.9239766081871345,
#  0.935672514619883,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.935672514619883,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.935672514619883,
#  0.9415204678362573]

# %%
# Plot of K values and Scores
#scaled
plt.plot(range(1,20),scores,marker='o',markerfacecolor='r',linestyle='--')

# %%
#Without Scaling
plt.plot(range(1,20),scores1,marker='o',markerfacecolor='r',linestyle='--')

# %%
# Optimum k value=7
#scaled
final_model = KNeighborsClassifier(n_neighbors=7,metric='euclidean')
final_model.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
# Without Scaling
final_model1 = KNeighborsClassifier(n_neighbors=9,metric='euclidean')
final_model1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                      weights='uniform')

# %%
# Prediction on training data
#scaled
final_train_pred = final_model.predict(scaled_X_train)
final_train_pred
# Out:
# array(['B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M',
#        'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M',
#        'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B',
# ...

# %%
#Without Scaling
final_train_pred1 = final_model1.predict(X_train)
final_train_pred1
# Out:
# array(['B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M',
#        'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B',
# ...

# %%
#scaled
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_train,final_train_pred),annot=True,fmt='d')

# %%
#Without Scaling
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_train,final_train_pred1),annot=True,fmt='d')

# %%
#scaled
##classification report

print(classification_report(y_train,final_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.97      0.99      0.98       243
#            M       0.99      0.95      0.97       155
#
#     accuracy                           0.97       398
#    macro avg       0.98      0.97      0.97       398
# weighted avg       0.98      0.97      0.97       398

# %%
# Without Scaling

print(classification_report(y_train,final_train_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.94      0.96      0.95       243
#            M       0.93      0.91      0.92       155
#
#     accuracy                           0.94       398
#    macro avg       0.94      0.93      0.94       398
# weighted avg       0.94      0.94      0.94       398

# %%
# Prediction on Test Data
#scaled
final_test_pred = final_model.predict(scaled_X_test) #y_test
final_test_pred
# Out:
# array(['M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'M',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M'], dtype=object)

# %%
#without scaling
final_test_pred1 = final_model1.predict(X_test) #y_test
final_test_pred1
# Out:
# array(['M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M',
#        'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'M',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B'], dtype=object)

# %%
#Confusion_matrix(actualValues,predictedValues)
#scaled
# Compare actual values of test data(y_test) and final_test_pred(model predicted values)
sns.heatmap(confusion_matrix(y_test,final_test_pred),annot=True,fmt='d')

# %%
# Without Scaling
sns.heatmap(confusion_matrix(y_test,final_test_pred1),annot=True,fmt='d')

# %%
# scaling
print(classification_report(y_test,final_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.97      0.96      0.97       114
#            M       0.93      0.95      0.94        57
#
#     accuracy                           0.96       171
#    macro avg       0.95      0.96      0.95       171
# weighted avg       0.96      0.96      0.96       171

# %%
#Without Scaling
print(classification_report(y_test,final_test_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      0.96      0.96       114
#            M       0.93      0.89      0.91        57
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.93      0.93       171
# weighted avg       0.94      0.94      0.94       171
